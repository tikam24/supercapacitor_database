# %%
import pandas as pd
import openpyxl
import requests
import json
import logging

# %%
def abstract_scraper(text_file, MY_API_KEY, serial_number):

    df = pd.DataFrame(columns =['EID', 'Title', 'Journal', 'DOI','S.No.'])
    i = 0
    
    with open(text_file, "r") as f:
        # Skip the first line of the file which contains the header
        # f.readline()                                
        # Loop over each line in the file to get the EIDs and fetch the abstracts
        for line in f:
                        
            eid = line.strip().split()[1]
            print(eid)
            
            resp = requests.get(f"https://api.elsevier.com/content/abstract/eid/{eid}",
                                headers={'Accept':'application/json', 'X-ELS-APIKey': MY_API_KEY})
            
            # Parsing the response to get the abstract and print it
            response_json = resp.json()
            try:
                abstract = response_json['abstracts-retrieval-response']['coredata']['dc:description']                         

                with open(f"abstract/{eid}.txt", "w", encoding="utf-8") as abstract_file:
                    abstract_file.write(abstract)
            
                print(f"Abstract for EID {eid} saved to abstract_{serial_number}.txt")
                print("="*80)
                
            except Exception as e:
                logging.exception(f"Error occurred: {str(e)}")
                print("Error occurred:", str(e))
                pass
            try:
                df.loc[serial_number, ['EID']] = eid
            except KeyError:
                df.loc[serial_number, ['EID']] = None                

            try:
                title = response_json['abstracts-retrieval-response']['coredata']['dc:title']
                df.loc[serial_number, ['Title']] = title
            except KeyError:
                df.loc[serial_number, ['Title']] = None                

            try:
                journal = response_json['abstracts-retrieval-response']['coredata']['prism:publicationName']
                df.loc[serial_number, ['Journal']] = journal
            except KeyError:
                df.loc[serial_number, ['Journal']] = None               

            try:
                dois = response_json['abstracts-retrieval-response']['coredata']['prism:doi']
                df.loc[serial_number, ['DOI']] = dois
            except KeyError:
                df.loc[serial_number, ['DOI']] = None

            df.loc[serial_number, ['S.No.']] = serial_number

            serial_number += 1
            # f.readable()
            
            i+=1
            if i == 4000:
                break
        
        li = f.read()
        with open('eid2.txt', 'w') as f1:
            f1.write(li)                   
    return df, serial_number

# %%
MY_API_KEY = '2a255c816bb46595e4459f5ed9800366'              
serial_num = 37381

# %%
newdf = pd.DataFrame()
try:
    newdf, sn = abstract_scraper("eid2.txt", MY_API_KEY ,serial_num)
except:
    pass
    
newdf.to_excel(f'abstracts_details_{serial_num}_{sn-1}.xlsx', engine ='openpyxl', index = False)
  
print('Next Serial Number:', sn)
# Out:
# 2-s2.0-84999836299
# ERROR:root:Error occurred: 'dc:description'
# Traceback (most recent call last):
#   File "C:\Users\Tikam Soni\AppData\Local\Temp\ipykernel_42036\3502383103.py", line 21, in abstract_scraper
#     abstract = response_json['abstracts-retrieval-response']['coredata']['dc:description']
# KeyError: 'dc:description'
# Error occurred: 'dc:description'
# 2-s2.0-84997666934
# Abstract for EID 2-s2.0-84997666934 saved to abstract_37382.txt
# ================================================================================
# 2-s2.0-85027285905
# Abstract for EID 2-s2.0-85027285905 saved to abstract_37383.txt
# ================================================================================
# 2-s2.0-85017277185
# Abstract for EID 2-s2.0-85017277185 saved to abstract_37384.txt
# ================================================================================
# 2-s2.0-85015215777
# Abstract for EID 2-s2.0-85015215777 saved to abstract_37385.txt
# ================================================================================
# 2-s2.0-85014620318
# Abstract for EID 2-s2.0-85014620318 saved to abstract_37386.txt
# ================================================================================
# 2-s2.0-85014546107
# Abstract for EID 2-s2.0-85014546107 saved to abstract_37387.txt
# ================================================================================
# 2-s2.0-85014524941
# Abstract for EID 2-s2.0-85014524941 saved to abstract_37388.txt
# ================================================================================
# 2-s2.0-85014513128
# Abstract for EID 2-s2.0-85014513128 saved to abstract_37389.txt
# ================================================================================
# 2-s2.0-85008496978
# Abstract for EID 2-s2.0-85008496978 saved to abstract_37390.txt
# ================================================================================
# 2-s2.0-84998693455
# Abstract for EID 2-s2.0-84998693455 saved to abstract_37391.txt
# ================================================================================
# 2-s2.0-84996461298
# Abstract for EID 2-s2.0-84996461298 saved to abstract_37392.txt
# ================================================================================
# 2-s2.0-85014611601
# Abstract for EID 2-s2.0-85014611601 saved to abstract_37393.txt
# ================================================================================
# 2-s2.0-85012094069
# Abstract for EID 2-s2.0-85012094069 saved to abstract_37394.txt
# ================================================================================
# 2-s2.0-85007189751
# Abstract for EID 2-s2.0-85007189751 saved to abstract_37395.txt
# ================================================================================
# 2-s2.0-85041953375
# Abstract for EID 2-s2.0-85041953375 saved to abstract_37396.txt
# ================================================================================
# 2-s2.0-85038427395
# Abstract for EID 2-s2.0-85038427395 saved to abstract_37397.txt
# ================================================================================
# 2-s2.0-85033456297
# Abstract for EID 2-s2.0-85033456297 saved to abstract_37398.txt
# ================================================================================
# 2-s2.0-85028274605
# Abstract for EID 2-s2.0-85028274605 saved to abstract_37399.txt
# ================================================================================
# 2-s2.0-85028233988
# Abstract for EID 2-s2.0-85028233988 saved to abstract_37400.txt
# ================================================================================
# 2-s2.0-85027439868
# Abstract for EID 2-s2.0-85027439868 saved to abstract_37401.txt
# ================================================================================
# 2-s2.0-85021402181
# Abstract for EID 2-s2.0-85021402181 saved to abstract_37402.txt
# ================================================================================
# 2-s2.0-85020649978
# Abstract for EID 2-s2.0-85020649978 saved to abstract_37403.txt
# ================================================================================
# 2-s2.0-85019693820
# Abstract for EID 2-s2.0-85019693820 saved to abstract_37404.txt
# ================================================================================
# 2-s2.0-85019349063
# Abstract for EID 2-s2.0-85019349063 saved to abstract_37405.txt
# ================================================================================
# 2-s2.0-85019150288
# ERROR:root:Error occurred: 'dc:description'
# Traceback (most recent call last):
#   File "C:\Users\Tikam Soni\AppData\Local\Temp\ipykernel_42036\3502383103.py", line 21, in abstract_scraper
#     abstract = response_json['abstracts-retrieval-response']['coredata']['dc:description']
# KeyError: 'dc:description'
# Error occurred: 'dc:description'
# 2-s2.0-85019124155
# Abstract for EID 2-s2.0-85019124155 saved to abstract_37407.txt
# ================================================================================
# 2-s2.0-85018918499
# Abstract for EID 2-s2.0-85018918499 saved to abstract_37408.txt
# ================================================================================
# 2-s2.0-85018473295
# Abstract for EID 2-s2.0-85018473295 saved to abstract_37409.txt
# ================================================================================
# 2-s2.0-85018429529
# Abstract for EID 2-s2.0-85018429529 saved to abstract_37410.txt
# ================================================================================
# 2-s2.0-85018271691
# Abstract for EID 2-s2.0-85018271691 saved to abstract_37411.txt
# ================================================================================
# 2-s2.0-85017328676
# Abstract for EID 2-s2.0-85017328676 saved to abstract_37412.txt
# ================================================================================
# 2-s2.0-85016819670
# Abstract for EID 2-s2.0-85016819670 saved to abstract_37413.txt
# ================================================================================
# 2-s2.0-85016797860
# Abstract for EID 2-s2.0-85016797860 saved to abstract_37414.txt
# ================================================================================
# 2-s2.0-85016623625
# Abstract for EID 2-s2.0-85016623625 saved to abstract_37415.txt
# ================================================================================
# 2-s2.0-85016501569
# Abstract for EID 2-s2.0-85016501569 saved to abstract_37416.txt
# ================================================================================
# 2-s2.0-85015983425
# Abstract for EID 2-s2.0-85015983425 saved to abstract_37417.txt
# ================================================================================
# 2-s2.0-85015960712
# Abstract for EID 2-s2.0-85015960712 saved to abstract_37418.txt
# ================================================================================
# 2-s2.0-85015688388
# Abstract for EID 2-s2.0-85015688388 saved to abstract_37419.txt
# ================================================================================
# 2-s2.0-85015675067
# Abstract for EID 2-s2.0-85015675067 saved to abstract_37420.txt
# ================================================================================
# 2-s2.0-85015662122
# Abstract for EID 2-s2.0-85015662122 saved to abstract_37421.txt
# ================================================================================
# 2-s2.0-85015640904
# Abstract for EID 2-s2.0-85015640904 saved to abstract_37422.txt
# ================================================================================
# 2-s2.0-85015617152
# Abstract for EID 2-s2.0-85015617152 saved to abstract_37423.txt
# ================================================================================
# 2-s2.0-85015246627
# Abstract for EID 2-s2.0-85015246627 saved to abstract_37424.txt
# ================================================================================
# 2-s2.0-85014662660
# Abstract for EID 2-s2.0-85014662660 saved to abstract_37425.txt
# ================================================================================
# 2-s2.0-85014590434
# Abstract for EID 2-s2.0-85014590434 saved to abstract_37426.txt
# ================================================================================
# 2-s2.0-85014298164
# Abstract for EID 2-s2.0-85014298164 saved to abstract_37427.txt
# ================================================================================
# 2-s2.0-85014276241
# Abstract for EID 2-s2.0-85014276241 saved to abstract_37428.txt
# ================================================================================
# 2-s2.0-85014241664
# Abstract for EID 2-s2.0-85014241664 saved to abstract_37429.txt
# ================================================================================
# 2-s2.0-85014133076
# Abstract for EID 2-s2.0-85014133076 saved to abstract_37430.txt
# ================================================================================
# 2-s2.0-85014091329
# Abstract for EID 2-s2.0-85014091329 saved to abstract_37431.txt
# ================================================================================
# 2-s2.0-85013918053
# Abstract for EID 2-s2.0-85013918053 saved to abstract_37432.txt
# ================================================================================
# 2-s2.0-85013830986
# Abstract for EID 2-s2.0-85013830986 saved to abstract_37433.txt
# ================================================================================
# 2-s2.0-85013483686
# Abstract for EID 2-s2.0-85013483686 saved to abstract_37434.txt
# ================================================================================
# 2-s2.0-85013197065
# Abstract for EID 2-s2.0-85013197065 saved to abstract_37435.txt
# ================================================================================
# 2-s2.0-85013124663
# Abstract for EID 2-s2.0-85013124663 saved to abstract_37436.txt
# ================================================================================
# 2-s2.0-85012982099
# Abstract for EID 2-s2.0-85012982099 saved to abstract_37437.txt
# ================================================================================
# 2-s2.0-85012308630
# Abstract for EID 2-s2.0-85012308630 saved to abstract_37438.txt
# ================================================================================
# 2-s2.0-85012288950
# Abstract for EID 2-s2.0-85012288950 saved to abstract_37439.txt
# ================================================================================
# 2-s2.0-85012207002
# Abstract for EID 2-s2.0-85012207002 saved to abstract_37440.txt
# ================================================================================
# 2-s2.0-85012123699
# Abstract for EID 2-s2.0-85012123699 saved to abstract_37441.txt
# ================================================================================
# 2-s2.0-85012044238
# Abstract for EID 2-s2.0-85012044238 saved to abstract_37442.txt
# ================================================================================
# 2-s2.0-85012013284
# Abstract for EID 2-s2.0-85012013284 saved to abstract_37443.txt
# ================================================================================
# 2-s2.0-85011552343
# Abstract for EID 2-s2.0-85011552343 saved to abstract_37444.txt
# ================================================================================
# 2-s2.0-85011406396
# Abstract for EID 2-s2.0-85011406396 saved to abstract_37445.txt
# ================================================================================
# 2-s2.0-85011320916
# Abstract for EID 2-s2.0-85011320916 saved to abstract_37446.txt
# ================================================================================
# 2-s2.0-85011000733
# Abstract for EID 2-s2.0-85011000733 saved to abstract_37447.txt
# ================================================================================
# 2-s2.0-85010991382
# Abstract for EID 2-s2.0-85010991382 saved to abstract_37448.txt
# ================================================================================
# 2-s2.0-85010953155
# Abstract for EID 2-s2.0-85010953155 saved to abstract_37449.txt
# ================================================================================
# 2-s2.0-85010901197
# Abstract for EID 2-s2.0-85010901197 saved to abstract_37450.txt
# ================================================================================
# 2-s2.0-85010876694
# Abstract for EID 2-s2.0-85010876694 saved to abstract_37451.txt
# ================================================================================
# 2-s2.0-85010843619
# Abstract for EID 2-s2.0-85010843619 saved to abstract_37452.txt
# ================================================================================
# 2-s2.0-85010637591
# Abstract for EID 2-s2.0-85010637591 saved to abstract_37453.txt
# ================================================================================
# 2-s2.0-85010458416
# Abstract for EID 2-s2.0-85010458416 saved to abstract_37454.txt
# ================================================================================
# 2-s2.0-85009987894
# Abstract for EID 2-s2.0-85009987894 saved to abstract_37455.txt
# ================================================================================
# 2-s2.0-85009958046
# Abstract for EID 2-s2.0-85009958046 saved to abstract_37456.txt
# ================================================================================
# 2-s2.0-85009919665
# Abstract for EID 2-s2.0-85009919665 saved to abstract_37457.txt
# ================================================================================
# 2-s2.0-85009877621
# Abstract for EID 2-s2.0-85009877621 saved to abstract_37458.txt
# ================================================================================
# 2-s2.0-85009872727
# Abstract for EID 2-s2.0-85009872727 saved to abstract_37459.txt
# ================================================================================
# 2-s2.0-85009433904
# Abstract for EID 2-s2.0-85009433904 saved to abstract_37460.txt
# ================================================================================
# 2-s2.0-85008233205
# Abstract for EID 2-s2.0-85008233205 saved to abstract_37461.txt
# ================================================================================
# 2-s2.0-85008227615
# Abstract for EID 2-s2.0-85008227615 saved to abstract_37462.txt
# ================================================================================
# 2-s2.0-85007180513
# Abstract for EID 2-s2.0-85007180513 saved to abstract_37463.txt
# ================================================================================
# 2-s2.0-85006983419
# Abstract for EID 2-s2.0-85006983419 saved to abstract_37464.txt
# ================================================================================
# 2-s2.0-85006851618
# Abstract for EID 2-s2.0-85006851618 saved to abstract_37465.txt
# ================================================================================
# 2-s2.0-85006215400
# Abstract for EID 2-s2.0-85006215400 saved to abstract_37466.txt
# ================================================================================
# 2-s2.0-85006153419
# Abstract for EID 2-s2.0-85006153419 saved to abstract_37467.txt
# ================================================================================
# 2-s2.0-85001029992
# Abstract for EID 2-s2.0-85001029992 saved to abstract_37468.txt
# ================================================================================
# 2-s2.0-85000868508
# Abstract for EID 2-s2.0-85000868508 saved to abstract_37469.txt
# ================================================================================
# 2-s2.0-84998673701
# Abstract for EID 2-s2.0-84998673701 saved to abstract_37470.txt
# ================================================================================
# 2-s2.0-84997077965
# Abstract for EID 2-s2.0-84997077965 saved to abstract_37471.txt
# ================================================================================
# 2-s2.0-84996479954
# Abstract for EID 2-s2.0-84996479954 saved to abstract_37472.txt
# ================================================================================
# 2-s2.0-84995489157
# Abstract for EID 2-s2.0-84995489157 saved to abstract_37473.txt
# ================================================================================
# 2-s2.0-84994076389
# Abstract for EID 2-s2.0-84994076389 saved to abstract_37474.txt
# ================================================================================
# 2-s2.0-84991777615
# Abstract for EID 2-s2.0-84991777615 saved to abstract_37475.txt
# ================================================================================
# 2-s2.0-84991758940
# Abstract for EID 2-s2.0-84991758940 saved to abstract_37476.txt
# ================================================================================
# 2-s2.0-84991051813
# Abstract for EID 2-s2.0-84991051813 saved to abstract_37477.txt
# ================================================================================
# 2-s2.0-84990943235
# Abstract for EID 2-s2.0-84990943235 saved to abstract_37478.txt
# ================================================================================
# 2-s2.0-84990878527
# Abstract for EID 2-s2.0-84990878527 saved to abstract_37479.txt
# ================================================================================
# 2-s2.0-84988422254
# Abstract for EID 2-s2.0-84988422254 saved to abstract_37480.txt
# ================================================================================
# 2-s2.0-84988360746
# Abstract for EID 2-s2.0-84988360746 saved to abstract_37481.txt
# ================================================================================
# 2-s2.0-84964663610
# Abstract for EID 2-s2.0-84964663610 saved to abstract_37482.txt
# ================================================================================
# 2-s2.0-85096592319
# Abstract for EID 2-s2.0-85096592319 saved to abstract_37483.txt
# ================================================================================
# 2-s2.0-85083450373
# Abstract for EID 2-s2.0-85083450373 saved to abstract_37484.txt
# ================================================================================
# 2-s2.0-85027944924
# Abstract for EID 2-s2.0-85027944924 saved to abstract_37485.txt
# ================================================================================
# 2-s2.0-85016006482
# Abstract for EID 2-s2.0-85016006482 saved to abstract_37486.txt
# ================================================================================
# 2-s2.0-85015173026
# Abstract for EID 2-s2.0-85015173026 saved to abstract_37487.txt
# ================================================================================
# 2-s2.0-85015171691
# Abstract for EID 2-s2.0-85015171691 saved to abstract_37488.txt
# ================================================================================
# 2-s2.0-85014232412
# Abstract for EID 2-s2.0-85014232412 saved to abstract_37489.txt
# ================================================================================
# 2-s2.0-85014230226
# Abstract for EID 2-s2.0-85014230226 saved to abstract_37490.txt
# ================================================================================
# 2-s2.0-85014199391
# Abstract for EID 2-s2.0-85014199391 saved to abstract_37491.txt
# ================================================================================
# 2-s2.0-85014146921
# Abstract for EID 2-s2.0-85014146921 saved to abstract_37492.txt
# ================================================================================
# 2-s2.0-85013995651
# Abstract for EID 2-s2.0-85013995651 saved to abstract_37493.txt
# ================================================================================
# 2-s2.0-85006999691
# Abstract for EID 2-s2.0-85006999691 saved to abstract_37494.txt
# ================================================================================
# 2-s2.0-85006942331
# Abstract for EID 2-s2.0-85006942331 saved to abstract_37495.txt
# ================================================================================
# 2-s2.0-85006856347
# Abstract for EID 2-s2.0-85006856347 saved to abstract_37496.txt
# ================================================================================
# 2-s2.0-85006804306
# Abstract for EID 2-s2.0-85006804306 saved to abstract_37497.txt
# ================================================================================
# 2-s2.0-85006791658
# Abstract for EID 2-s2.0-85006791658 saved to abstract_37498.txt
# ================================================================================
# 2-s2.0-85006757114
# Abstract for EID 2-s2.0-85006757114 saved to abstract_37499.txt
# ================================================================================
# 2-s2.0-85006725016
# Abstract for EID 2-s2.0-85006725016 saved to abstract_37500.txt
# ================================================================================
# 2-s2.0-85006410529
# Abstract for EID 2-s2.0-85006410529 saved to abstract_37501.txt
# ================================================================================
# 2-s2.0-85006276861
# Abstract for EID 2-s2.0-85006276861 saved to abstract_37502.txt
# ================================================================================
# 2-s2.0-85006136287
# Abstract for EID 2-s2.0-85006136287 saved to abstract_37503.txt
# ================================================================================
# 2-s2.0-85015392053
# Abstract for EID 2-s2.0-85015392053 saved to abstract_37504.txt
# ================================================================================
# 2-s2.0-85014091406
# Abstract for EID 2-s2.0-85014091406 saved to abstract_37505.txt
# ================================================================================
# 2-s2.0-85014090465
# Abstract for EID 2-s2.0-85014090465 saved to abstract_37506.txt
# ================================================================================
# 2-s2.0-85053920123
# Abstract for EID 2-s2.0-85053920123 saved to abstract_37507.txt
# ================================================================================
# 2-s2.0-85042706544
# Abstract for EID 2-s2.0-85042706544 saved to abstract_37508.txt
# ================================================================================
# 2-s2.0-85006844221
# Abstract for EID 2-s2.0-85006844221 saved to abstract_37509.txt
# ================================================================================
# 2-s2.0-85006172745
# Abstract for EID 2-s2.0-85006172745 saved to abstract_37510.txt
# ================================================================================
# 2-s2.0-85006113585
# Abstract for EID 2-s2.0-85006113585 saved to abstract_37511.txt
# ================================================================================
# 2-s2.0-85005773765
# Abstract for EID 2-s2.0-85005773765 saved to abstract_37512.txt
# ================================================================================
# 2-s2.0-84992646467
# Abstract for EID 2-s2.0-84992646467 saved to abstract_37513.txt
# ================================================================================
# 2-s2.0-85014416730
# Abstract for EID 2-s2.0-85014416730 saved to abstract_37514.txt
# ================================================================================
# 2-s2.0-85006977002
# Abstract for EID 2-s2.0-85006977002 saved to abstract_37515.txt
# ================================================================================
# 2-s2.0-85021061243
# Abstract for EID 2-s2.0-85021061243 saved to abstract_37516.txt
# ================================================================================
# 2-s2.0-85015737359
# Abstract for EID 2-s2.0-85015737359 saved to abstract_37517.txt
# ================================================================================
# 2-s2.0-85015734943
# Abstract for EID 2-s2.0-85015734943 saved to abstract_37518.txt
# ================================================================================
# 2-s2.0-85015725047
# Abstract for EID 2-s2.0-85015725047 saved to abstract_37519.txt
# ================================================================================
# 2-s2.0-85013774771
# Abstract for EID 2-s2.0-85013774771 saved to abstract_37520.txt
# ================================================================================
# 2-s2.0-85013290456
# Abstract for EID 2-s2.0-85013290456 saved to abstract_37521.txt
# ================================================================================
# 2-s2.0-85009865521
# Abstract for EID 2-s2.0-85009865521 saved to abstract_37522.txt
# ================================================================================
# 2-s2.0-85013435880
# Abstract for EID 2-s2.0-85013435880 saved to abstract_37523.txt
# ================================================================================
# 2-s2.0-85013413540
# Abstract for EID 2-s2.0-85013413540 saved to abstract_37524.txt
# ================================================================================
# 2-s2.0-85010208968
# Abstract for EID 2-s2.0-85010208968 saved to abstract_37525.txt
# ================================================================================
# 2-s2.0-85009957900
# Abstract for EID 2-s2.0-85009957900 saved to abstract_37526.txt
# ================================================================================
# 2-s2.0-84996843285
# Abstract for EID 2-s2.0-84996843285 saved to abstract_37527.txt
# ================================================================================
# 2-s2.0-85016120851
# Abstract for EID 2-s2.0-85016120851 saved to abstract_37528.txt
# ================================================================================
# 2-s2.0-85013466551
# Abstract for EID 2-s2.0-85013466551 saved to abstract_37529.txt
# ================================================================================
# 2-s2.0-85011397680
# Abstract for EID 2-s2.0-85011397680 saved to abstract_37530.txt
# ================================================================================
# 2-s2.0-85011372925
# Abstract for EID 2-s2.0-85011372925 saved to abstract_37531.txt
# ================================================================================
# 2-s2.0-85015224244
# Abstract for EID 2-s2.0-85015224244 saved to abstract_37532.txt
# ================================================================================
# 2-s2.0-85013229451
# Abstract for EID 2-s2.0-85013229451 saved to abstract_37533.txt
# ================================================================================
# 2-s2.0-85010433496
# Abstract for EID 2-s2.0-85010433496 saved to abstract_37534.txt
# ================================================================================
# 2-s2.0-85010427120
# Abstract for EID 2-s2.0-85010427120 saved to abstract_37535.txt
# ================================================================================
# 2-s2.0-85010295329
# Abstract for EID 2-s2.0-85010295329 saved to abstract_37536.txt
# ================================================================================
# 2-s2.0-85009998108
# Abstract for EID 2-s2.0-85009998108 saved to abstract_37537.txt
# ================================================================================
# 2-s2.0-85009986766
# Abstract for EID 2-s2.0-85009986766 saved to abstract_37538.txt
# ================================================================================
# 2-s2.0-85009957293
# Abstract for EID 2-s2.0-85009957293 saved to abstract_37539.txt
# ================================================================================
# 2-s2.0-85009953632
# Abstract for EID 2-s2.0-85009953632 saved to abstract_37540.txt
# ================================================================================
# 2-s2.0-85009950341
# Abstract for EID 2-s2.0-85009950341 saved to abstract_37541.txt
# ================================================================================
# 2-s2.0-85009949467
# Abstract for EID 2-s2.0-85009949467 saved to abstract_37542.txt
# ================================================================================
# 2-s2.0-85009863297
# Abstract for EID 2-s2.0-85009863297 saved to abstract_37543.txt
# ================================================================================
# 2-s2.0-85009384746
# Abstract for EID 2-s2.0-85009384746 saved to abstract_37544.txt
# ================================================================================
# 2-s2.0-85009247634
# Abstract for EID 2-s2.0-85009247634 saved to abstract_37545.txt
# ================================================================================
# 2-s2.0-85014574443
# Abstract for EID 2-s2.0-85014574443 saved to abstract_37546.txt
# ================================================================================
# 2-s2.0-85014526587
# Abstract for EID 2-s2.0-85014526587 saved to abstract_37547.txt
# ================================================================================
# 2-s2.0-85012979458
# Abstract for EID 2-s2.0-85012979458 saved to abstract_37548.txt
# ================================================================================
# 2-s2.0-85007331161
# Abstract for EID 2-s2.0-85007331161 saved to abstract_37549.txt
# ================================================================================
# 2-s2.0-85015288227
# Abstract for EID 2-s2.0-85015288227 saved to abstract_37550.txt
# ================================================================================
# 2-s2.0-85013157871
# Abstract for EID 2-s2.0-85013157871 saved to abstract_37551.txt
# ================================================================================
# 2-s2.0-85013130847
# Abstract for EID 2-s2.0-85013130847 saved to abstract_37552.txt
# ================================================================================
# 2-s2.0-85013127862
# Abstract for EID 2-s2.0-85013127862 saved to abstract_37553.txt
# ================================================================================
# 2-s2.0-85013124330
# Abstract for EID 2-s2.0-85013124330 saved to abstract_37554.txt
# ================================================================================
# 2-s2.0-85010917498
# Abstract for EID 2-s2.0-85010917498 saved to abstract_37555.txt
# ================================================================================
# 2-s2.0-85006456808
# Abstract for EID 2-s2.0-85006456808 saved to abstract_37556.txt
# ================================================================================
# 2-s2.0-85006401323
# Abstract for EID 2-s2.0-85006401323 saved to abstract_37557.txt
# ================================================================================
# 2-s2.0-85006371046
# Abstract for EID 2-s2.0-85006371046 saved to abstract_37558.txt
# ================================================================================
# 2-s2.0-85006324687
# Abstract for EID 2-s2.0-85006324687 saved to abstract_37559.txt
# ================================================================================
# 2-s2.0-85002902290
# Abstract for EID 2-s2.0-85002902290 saved to abstract_37560.txt
# ================================================================================
# 2-s2.0-85002552781
# Abstract for EID 2-s2.0-85002552781 saved to abstract_37561.txt
# ================================================================================
# 2-s2.0-85000420322
# Abstract for EID 2-s2.0-85000420322 saved to abstract_37562.txt
# ================================================================================
# 2-s2.0-84999791353
# Abstract for EID 2-s2.0-84999791353 saved to abstract_37563.txt
# ================================================================================
# 2-s2.0-84999006665
# Abstract for EID 2-s2.0-84999006665 saved to abstract_37564.txt
# ================================================================================
# 2-s2.0-84998775165
# Abstract for EID 2-s2.0-84998775165 saved to abstract_37565.txt
# ================================================================================
# 2-s2.0-84996671198
# Abstract for EID 2-s2.0-84996671198 saved to abstract_37566.txt
# ================================================================================
# 2-s2.0-84994632123
# Abstract for EID 2-s2.0-84994632123 saved to abstract_37567.txt
# ================================================================================
# 2-s2.0-84994050010
# Abstract for EID 2-s2.0-84994050010 saved to abstract_37568.txt
# ================================================================================
# 2-s2.0-84990842291
# Abstract for EID 2-s2.0-84990842291 saved to abstract_37569.txt
# ================================================================================
# 2-s2.0-85012115851
# Abstract for EID 2-s2.0-85012115851 saved to abstract_37570.txt
# ================================================================================
# 2-s2.0-85015970842
# Abstract for EID 2-s2.0-85015970842 saved to abstract_37571.txt
# ================================================================================
# 2-s2.0-85015953874
# Abstract for EID 2-s2.0-85015953874 saved to abstract_37572.txt
# ================================================================================
# 2-s2.0-85015878346
# Abstract for EID 2-s2.0-85015878346 saved to abstract_37573.txt
# ================================================================================
# 2-s2.0-85015848633
# Abstract for EID 2-s2.0-85015848633 saved to abstract_37574.txt
# ================================================================================
# 2-s2.0-85015837889
# Abstract for EID 2-s2.0-85015837889 saved to abstract_37575.txt
# ================================================================================
# 2-s2.0-85015834936
# Abstract for EID 2-s2.0-85015834936 saved to abstract_37576.txt
# ================================================================================
# 2-s2.0-85015826942
# Abstract for EID 2-s2.0-85015826942 saved to abstract_37577.txt
# ================================================================================
# 2-s2.0-85015824721
# Abstract for EID 2-s2.0-85015824721 saved to abstract_37578.txt
# ================================================================================
# 2-s2.0-85015817894
# Abstract for EID 2-s2.0-85015817894 saved to abstract_37579.txt
# ================================================================================
# 2-s2.0-85014353219
# Abstract for EID 2-s2.0-85014353219 saved to abstract_37580.txt
# ================================================================================
# 2-s2.0-85014316921
# Abstract for EID 2-s2.0-85014316921 saved to abstract_37581.txt
# ================================================================================
# 2-s2.0-85008240287
# Abstract for EID 2-s2.0-85008240287 saved to abstract_37582.txt
# ================================================================================
# 2-s2.0-85018808931
# Abstract for EID 2-s2.0-85018808931 saved to abstract_37583.txt
# ================================================================================
# 2-s2.0-85017366212
# Abstract for EID 2-s2.0-85017366212 saved to abstract_37584.txt
# ================================================================================
# 2-s2.0-85012050590
# Abstract for EID 2-s2.0-85012050590 saved to abstract_37585.txt
# ================================================================================
# 2-s2.0-85011999981
# Abstract for EID 2-s2.0-85011999981 saved to abstract_37586.txt
# ================================================================================
# 2-s2.0-85010193040
# Abstract for EID 2-s2.0-85010193040 saved to abstract_37587.txt
# ================================================================================
# 2-s2.0-85010039002
# Abstract for EID 2-s2.0-85010039002 saved to abstract_37588.txt
# ================================================================================
# 2-s2.0-85009889610
# Abstract for EID 2-s2.0-85009889610 saved to abstract_37589.txt
# ================================================================================
# 2-s2.0-85009270163
# Abstract for EID 2-s2.0-85009270163 saved to abstract_37590.txt
# ================================================================================
# 2-s2.0-85009128697
# Abstract for EID 2-s2.0-85009128697 saved to abstract_37591.txt
# ================================================================================
# 2-s2.0-85009060603
# Abstract for EID 2-s2.0-85009060603 saved to abstract_37592.txt
# ================================================================================
# 2-s2.0-85008471411
# Abstract for EID 2-s2.0-85008471411 saved to abstract_37593.txt
# ================================================================================
# 2-s2.0-85008400460
# Abstract for EID 2-s2.0-85008400460 saved to abstract_37594.txt
# ================================================================================
# 2-s2.0-85008312042
# Abstract for EID 2-s2.0-85008312042 saved to abstract_37595.txt
# ================================================================================
# 2-s2.0-84990020267
# Abstract for EID 2-s2.0-84990020267 saved to abstract_37596.txt
# ================================================================================
# 2-s2.0-85015455451
# Abstract for EID 2-s2.0-85015455451 saved to abstract_37597.txt
# ================================================================================
# 2-s2.0-85011990700
# Abstract for EID 2-s2.0-85011990700 saved to abstract_37598.txt
# ================================================================================
# 2-s2.0-85011977106
# Abstract for EID 2-s2.0-85011977106 saved to abstract_37599.txt
# ================================================================================
# 2-s2.0-85011968919
# Abstract for EID 2-s2.0-85011968919 saved to abstract_37600.txt
# ================================================================================
# 2-s2.0-85006172657
# Abstract for EID 2-s2.0-85006172657 saved to abstract_37601.txt
# ================================================================================
# 2-s2.0-84992379112
# Abstract for EID 2-s2.0-84992379112 saved to abstract_37602.txt
# ================================================================================
# 2-s2.0-84991212126
# Abstract for EID 2-s2.0-84991212126 saved to abstract_37603.txt
# ================================================================================
# 2-s2.0-85015255127
# Abstract for EID 2-s2.0-85015255127 saved to abstract_37604.txt
# ================================================================================
# 2-s2.0-85015146172
# Abstract for EID 2-s2.0-85015146172 saved to abstract_37605.txt
# ================================================================================
# 2-s2.0-85013040639
# Abstract for EID 2-s2.0-85013040639 saved to abstract_37606.txt
# ================================================================================
# 2-s2.0-85011659753
# Abstract for EID 2-s2.0-85011659753 saved to abstract_37607.txt
# ================================================================================
# 2-s2.0-85011649773
# Abstract for EID 2-s2.0-85011649773 saved to abstract_37608.txt
# ================================================================================
# 2-s2.0-84994507747
# Abstract for EID 2-s2.0-84994507747 saved to abstract_37609.txt
# ================================================================================
# 2-s2.0-85027190487
# Abstract for EID 2-s2.0-85027190487 saved to abstract_37610.txt
# ================================================================================
# 2-s2.0-85027118034
# Abstract for EID 2-s2.0-85027118034 saved to abstract_37611.txt
# ================================================================================
# 2-s2.0-85011628969
# Abstract for EID 2-s2.0-85011628969 saved to abstract_37612.txt
# ================================================================================
# 2-s2.0-85009078256
# Abstract for EID 2-s2.0-85009078256 saved to abstract_37613.txt
# ================================================================================
# 2-s2.0-85009059956
# Abstract for EID 2-s2.0-85009059956 saved to abstract_37614.txt
# ================================================================================
# 2-s2.0-85006069160
# Abstract for EID 2-s2.0-85006069160 saved to abstract_37615.txt
# ================================================================================
# 2-s2.0-84997079160
# Abstract for EID 2-s2.0-84997079160 saved to abstract_37616.txt
# ================================================================================
# 2-s2.0-85015421849
# Abstract for EID 2-s2.0-85015421849 saved to abstract_37617.txt
# ================================================================================
# 2-s2.0-85015402196
# Abstract for EID 2-s2.0-85015402196 saved to abstract_37618.txt
# ================================================================================
# 2-s2.0-85015362436
# Abstract for EID 2-s2.0-85015362436 saved to abstract_37619.txt
# ================================================================================
# 2-s2.0-85015170503
# Abstract for EID 2-s2.0-85015170503 saved to abstract_37620.txt
# ================================================================================
# 2-s2.0-85015164384
# Abstract for EID 2-s2.0-85015164384 saved to abstract_37621.txt
# ================================================================================
# 2-s2.0-85010976136
# Abstract for EID 2-s2.0-85010976136 saved to abstract_37622.txt
# ================================================================================
# 2-s2.0-84992170482
# Abstract for EID 2-s2.0-84992170482 saved to abstract_37623.txt
# ================================================================================
# 2-s2.0-85092426882
# Abstract for EID 2-s2.0-85092426882 saved to abstract_37624.txt
# ================================================================================
# 2-s2.0-85059742812
# Abstract for EID 2-s2.0-85059742812 saved to abstract_37625.txt
# ================================================================================
# 2-s2.0-85027010517
# Abstract for EID 2-s2.0-85027010517 saved to abstract_37626.txt
# ================================================================================
# 2-s2.0-85026745046
# Abstract for EID 2-s2.0-85026745046 saved to abstract_37627.txt
# ================================================================================
# 2-s2.0-85019610383
# Abstract for EID 2-s2.0-85019610383 saved to abstract_37628.txt
# ================================================================================
# 2-s2.0-85019590703
# Abstract for EID 2-s2.0-85019590703 saved to abstract_37629.txt
# ================================================================================
# 2-s2.0-85018901952
# Abstract for EID 2-s2.0-85018901952 saved to abstract_37630.txt
# ================================================================================
# 2-s2.0-85017635873
# Abstract for EID 2-s2.0-85017635873 saved to abstract_37631.txt
# ================================================================================
# 2-s2.0-85017244767
# Abstract for EID 2-s2.0-85017244767 saved to abstract_37632.txt
# ================================================================================
# 2-s2.0-85015445394
# Abstract for EID 2-s2.0-85015445394 saved to abstract_37633.txt
# ================================================================================
# 2-s2.0-85015398238
# Abstract for EID 2-s2.0-85015398238 saved to abstract_37634.txt
# ================================================================================
# 2-s2.0-85015321880
# Abstract for EID 2-s2.0-85015321880 saved to abstract_37635.txt
# ================================================================================
# 2-s2.0-85014916175
# Abstract for EID 2-s2.0-85014916175 saved to abstract_37636.txt
# ================================================================================
# 2-s2.0-85014868877
# Abstract for EID 2-s2.0-85014868877 saved to abstract_37637.txt
# ================================================================================
# 2-s2.0-85014824654
# Abstract for EID 2-s2.0-85014824654 saved to abstract_37638.txt
# ================================================================================
# 2-s2.0-85014814357
# Abstract for EID 2-s2.0-85014814357 saved to abstract_37639.txt
# ================================================================================
# 2-s2.0-85014766778
# Abstract for EID 2-s2.0-85014766778 saved to abstract_37640.txt
# ================================================================================
# 2-s2.0-85014355337
# Abstract for EID 2-s2.0-85014355337 saved to abstract_37641.txt
# ================================================================================
# 2-s2.0-85014327277
# Abstract for EID 2-s2.0-85014327277 saved to abstract_37642.txt
# ================================================================================
# 2-s2.0-85014324269
# Abstract for EID 2-s2.0-85014324269 saved to abstract_37643.txt
# ================================================================================
# 2-s2.0-85014321695
# Abstract for EID 2-s2.0-85014321695 saved to abstract_37644.txt
# ================================================================================
# 2-s2.0-85014110817
# Abstract for EID 2-s2.0-85014110817 saved to abstract_37645.txt
# ================================================================================
# 2-s2.0-85013243556
# Abstract for EID 2-s2.0-85013243556 saved to abstract_37646.txt
# ================================================================================
# 2-s2.0-85013200675
# Abstract for EID 2-s2.0-85013200675 saved to abstract_37647.txt
# ================================================================================
# 2-s2.0-85012956259
# Abstract for EID 2-s2.0-85012956259 saved to abstract_37648.txt
# ================================================================================
# 2-s2.0-85012195223
# Abstract for EID 2-s2.0-85012195223 saved to abstract_37649.txt
# ================================================================================
# 2-s2.0-85011931363
# Abstract for EID 2-s2.0-85011931363 saved to abstract_37650.txt
# ================================================================================
# 2-s2.0-85011824666
# Abstract for EID 2-s2.0-85011824666 saved to abstract_37651.txt
# ================================================================================
# 2-s2.0-85011695795
# Abstract for EID 2-s2.0-85011695795 saved to abstract_37652.txt
# ================================================================================
# 2-s2.0-85011691160
# Abstract for EID 2-s2.0-85011691160 saved to abstract_37653.txt
# ================================================================================
# 2-s2.0-85011635956
# Abstract for EID 2-s2.0-85011635956 saved to abstract_37654.txt
# ================================================================================
# 2-s2.0-85010903686
# Abstract for EID 2-s2.0-85010903686 saved to abstract_37655.txt
# ================================================================================
# 2-s2.0-85010210691
# Abstract for EID 2-s2.0-85010210691 saved to abstract_37656.txt
# ================================================================================
# 2-s2.0-85009446562
# Abstract for EID 2-s2.0-85009446562 saved to abstract_37657.txt
# ================================================================================
# 2-s2.0-85009080604
# Abstract for EID 2-s2.0-85009080604 saved to abstract_37658.txt
# ================================================================================
# 2-s2.0-85008965833
# Abstract for EID 2-s2.0-85008965833 saved to abstract_37659.txt
# ================================================================================
# 2-s2.0-85008945659
# Abstract for EID 2-s2.0-85008945659 saved to abstract_37660.txt
# ================================================================================
# 2-s2.0-85008622493
# Abstract for EID 2-s2.0-85008622493 saved to abstract_37661.txt
# ================================================================================
# 2-s2.0-85008406273
# Abstract for EID 2-s2.0-85008406273 saved to abstract_37662.txt
# ================================================================================
# 2-s2.0-85008402574
# Abstract for EID 2-s2.0-85008402574 saved to abstract_37663.txt
# ================================================================================
# 2-s2.0-85008391438
# Abstract for EID 2-s2.0-85008391438 saved to abstract_37664.txt
# ================================================================================
# 2-s2.0-85008323113
# Abstract for EID 2-s2.0-85008323113 saved to abstract_37665.txt
# ================================================================================
# 2-s2.0-85008263978
# Abstract for EID 2-s2.0-85008263978 saved to abstract_37666.txt
# ================================================================================
# 2-s2.0-85008254114
# Abstract for EID 2-s2.0-85008254114 saved to abstract_37667.txt
# ================================================================================
# 2-s2.0-85008253142
# ERROR:root:Error occurred: 'dc:description'
# Traceback (most recent call last):
#   File "C:\Users\Tikam Soni\AppData\Local\Temp\ipykernel_42036\3502383103.py", line 21, in abstract_scraper
#     abstract = response_json['abstracts-retrieval-response']['coredata']['dc:description']
# KeyError: 'dc:description'
# Error occurred: 'dc:description'
# 2-s2.0-85008193660
# Abstract for EID 2-s2.0-85008193660 saved to abstract_37669.txt
# ================================================================================
# 2-s2.0-85008145435
# ...
# 2-s2.0-84983423651
# Abstract for EID 2-s2.0-84983423651 saved to abstract_40250.txt
# ================================================================================
# 2-s2.0-84983417408
# Abstract for EID 2-s2.0-84983417408 saved to abstract_40251.txt
# ================================================================================
# 2-s2.0-84971576978
# Abstract for EID 2-s2.0-84971576978 saved to abstract_40252.txt
# ================================================================================
# 2-s2.0-84980002544
# Abstract for EID 2-s2.0-84980002544 saved to abstract_40253.txt
# ================================================================================
# 2-s2.0-84979464837
# Abstract for EID 2-s2.0-84979464837 saved to abstract_40254.txt
# ================================================================================
# 2-s2.0-84971246044
# Abstract for EID 2-s2.0-84971246044 saved to abstract_40255.txt
# ================================================================================
# 2-s2.0-84964507298
# Abstract for EID 2-s2.0-84964507298 saved to abstract_40256.txt
# ================================================================================
# 2-s2.0-84964336654
# Abstract for EID 2-s2.0-84964336654 saved to abstract_40257.txt
# ================================================================================
# 2-s2.0-84964330595
# Abstract for EID 2-s2.0-84964330595 saved to abstract_40258.txt
# ================================================================================
# 2-s2.0-84964325448
# Abstract for EID 2-s2.0-84964325448 saved to abstract_40259.txt
# ================================================================================
# 2-s2.0-84962873343
# Abstract for EID 2-s2.0-84962873343 saved to abstract_40260.txt
# ================================================================================
# 2-s2.0-84962836362
# Abstract for EID 2-s2.0-84962836362 saved to abstract_40261.txt
# ================================================================================
# 2-s2.0-84962376567
# Abstract for EID 2-s2.0-84962376567 saved to abstract_40262.txt
# ================================================================================
# 2-s2.0-84962338916
# Abstract for EID 2-s2.0-84962338916 saved to abstract_40263.txt
# ================================================================================
# 2-s2.0-84962163340
# Abstract for EID 2-s2.0-84962163340 saved to abstract_40264.txt
# ================================================================================
# 2-s2.0-84960844157
# Abstract for EID 2-s2.0-84960844157 saved to abstract_40265.txt
# ================================================================================
# 2-s2.0-84982839198
# Abstract for EID 2-s2.0-84982839198 saved to abstract_40266.txt
# ================================================================================
# 2-s2.0-85019499630
# Abstract for EID 2-s2.0-85019499630 saved to abstract_40267.txt
# ================================================================================
# 2-s2.0-84983651831
# Abstract for EID 2-s2.0-84983651831 saved to abstract_40268.txt
# ================================================================================
# 2-s2.0-84983409153
# Abstract for EID 2-s2.0-84983409153 saved to abstract_40269.txt
# ================================================================================
# 2-s2.0-84983354696
# Abstract for EID 2-s2.0-84983354696 saved to abstract_40270.txt
# ================================================================================
# 2-s2.0-84983301309
# Abstract for EID 2-s2.0-84983301309 saved to abstract_40271.txt
# ================================================================================
# 2-s2.0-84983296743
# Abstract for EID 2-s2.0-84983296743 saved to abstract_40272.txt
# ================================================================================
# 2-s2.0-84983288522
# Abstract for EID 2-s2.0-84983288522 saved to abstract_40273.txt
# ================================================================================
# 2-s2.0-84983284304
# Abstract for EID 2-s2.0-84983284304 saved to abstract_40274.txt
# ================================================================================
# 2-s2.0-84983247235
# Abstract for EID 2-s2.0-84983247235 saved to abstract_40275.txt
# ================================================================================
# 2-s2.0-84978884220
# Abstract for EID 2-s2.0-84978884220 saved to abstract_40276.txt
# ================================================================================
# 2-s2.0-84978829843
# Abstract for EID 2-s2.0-84978829843 saved to abstract_40277.txt
# ================================================================================
# 2-s2.0-84978375347
# Abstract for EID 2-s2.0-84978375347 saved to abstract_40278.txt
# ================================================================================
# 2-s2.0-84978286057
# ERROR:root:Error occurred: 'dc:description'
# Traceback (most recent call last):
#   File "C:\Users\Tikam Soni\AppData\Local\Temp\ipykernel_42036\3502383103.py", line 21, in abstract_scraper
#     abstract = response_json['abstracts-retrieval-response']['coredata']['dc:description']
# KeyError: 'dc:description'
# Error occurred: 'dc:description'
# 2-s2.0-84981492565
# Abstract for EID 2-s2.0-84981492565 saved to abstract_40280.txt
# ================================================================================
# 2-s2.0-84992382861
# Abstract for EID 2-s2.0-84992382861 saved to abstract_40281.txt
# ================================================================================
# 2-s2.0-84981352238
# Abstract for EID 2-s2.0-84981352238 saved to abstract_40282.txt
# ================================================================================
# 2-s2.0-84981350446
# Abstract for EID 2-s2.0-84981350446 saved to abstract_40283.txt
# ================================================================================
# 2-s2.0-84981313782
# Abstract for EID 2-s2.0-84981313782 saved to abstract_40284.txt
# ================================================================================
# 2-s2.0-84981306128
# Abstract for EID 2-s2.0-84981306128 saved to abstract_40285.txt
# ================================================================================
# 2-s2.0-85006186619
# Abstract for EID 2-s2.0-85006186619 saved to abstract_40286.txt
# ================================================================================
# 2-s2.0-84969972384
# Abstract for EID 2-s2.0-84969972384 saved to abstract_40287.txt
# ================================================================================
# 2-s2.0-84968791886
# Abstract for EID 2-s2.0-84968791886 saved to abstract_40288.txt
# ================================================================================
# 2-s2.0-84964894375
# Abstract for EID 2-s2.0-84964894375 saved to abstract_40289.txt
# ================================================================================
# 2-s2.0-84964835136
# Abstract for EID 2-s2.0-84964835136 saved to abstract_40290.txt
# ================================================================================
# 2-s2.0-84964809690
# Abstract for EID 2-s2.0-84964809690 saved to abstract_40291.txt
# ================================================================================
# 2-s2.0-84964690577
# Abstract for EID 2-s2.0-84964690577 saved to abstract_40292.txt
# ================================================================================
# 2-s2.0-84964669793
# Abstract for EID 2-s2.0-84964669793 saved to abstract_40293.txt
# ================================================================================
# 2-s2.0-84964669280
# Abstract for EID 2-s2.0-84964669280 saved to abstract_40294.txt
# ================================================================================
# 2-s2.0-84964584586
# Abstract for EID 2-s2.0-84964584586 saved to abstract_40295.txt
# ================================================================================
# 2-s2.0-84957828159
# Abstract for EID 2-s2.0-84957828159 saved to abstract_40296.txt
# ================================================================================
# 2-s2.0-84956644334
# Abstract for EID 2-s2.0-84956644334 saved to abstract_40297.txt
# ================================================================================
# 2-s2.0-84955303493
# Abstract for EID 2-s2.0-84955303493 saved to abstract_40298.txt
# ================================================================================
# 2-s2.0-84953432377
# Abstract for EID 2-s2.0-84953432377 saved to abstract_40299.txt
# ================================================================================
# 2-s2.0-85000427762
# Abstract for EID 2-s2.0-85000427762 saved to abstract_40300.txt
# ================================================================================
# 2-s2.0-84962778706
# ERROR:root:Error occurred: 'dc:description'
# Traceback (most recent call last):
#   File "C:\Users\Tikam Soni\AppData\Local\Temp\ipykernel_42036\3502383103.py", line 21, in abstract_scraper
#     abstract = response_json['abstracts-retrieval-response']['coredata']['dc:description']
# KeyError: 'dc:description'
# Error occurred: 'dc:description'
# 2-s2.0-84969914886
# Abstract for EID 2-s2.0-84969914886 saved to abstract_40302.txt
# ================================================================================
# 2-s2.0-85028245968
# Abstract for EID 2-s2.0-85028245968 saved to abstract_40303.txt
# ================================================================================
# 2-s2.0-85051604572
# Abstract for EID 2-s2.0-85051604572 saved to abstract_40304.txt
# ================================================================================
# 2-s2.0-84979695515
# Abstract for EID 2-s2.0-84979695515 saved to abstract_40305.txt
# ================================================================================
# 2-s2.0-84979035659
# Abstract for EID 2-s2.0-84979035659 saved to abstract_40306.txt
# ================================================================================
# 2-s2.0-84978999275
# Abstract for EID 2-s2.0-84978999275 saved to abstract_40307.txt
# ================================================================================
# 2-s2.0-84978975230
# Abstract for EID 2-s2.0-84978975230 saved to abstract_40308.txt
# ================================================================================
# 2-s2.0-84978959148
# Abstract for EID 2-s2.0-84978959148 saved to abstract_40309.txt
# ================================================================================
# 2-s2.0-84978929515
# Abstract for EID 2-s2.0-84978929515 saved to abstract_40310.txt
# ================================================================================
# 2-s2.0-84978033257
# Abstract for EID 2-s2.0-84978033257 saved to abstract_40311.txt
# ================================================================================
# 2-s2.0-84971254858
# Abstract for EID 2-s2.0-84971254858 saved to abstract_40312.txt
# ================================================================================
# 2-s2.0-84964336727
# Abstract for EID 2-s2.0-84964336727 saved to abstract_40313.txt
# ================================================================================
# 2-s2.0-84930080699
# Abstract for EID 2-s2.0-84930080699 saved to abstract_40314.txt
# ================================================================================
# 2-s2.0-85047726293
# Abstract for EID 2-s2.0-85047726293 saved to abstract_40315.txt
# ================================================================================
# 2-s2.0-85015848167
# Abstract for EID 2-s2.0-85015848167 saved to abstract_40316.txt
# ================================================================================
# 2-s2.0-85015843750
# Abstract for EID 2-s2.0-85015843750 saved to abstract_40317.txt
# ================================================================================
# 2-s2.0-85014885560
# Abstract for EID 2-s2.0-85014885560 saved to abstract_40318.txt
# ================================================================================
# 2-s2.0-84978755597
# Abstract for EID 2-s2.0-84978755597 saved to abstract_40319.txt
# ================================================================================
# 2-s2.0-84978085709
# Abstract for EID 2-s2.0-84978085709 saved to abstract_40320.txt
# ================================================================================
# 2-s2.0-85049226288
# Abstract for EID 2-s2.0-85049226288 saved to abstract_40321.txt
# ================================================================================
# 2-s2.0-85018502937
# Abstract for EID 2-s2.0-85018502937 saved to abstract_40322.txt
# ================================================================================
# 2-s2.0-85014646408
# Abstract for EID 2-s2.0-85014646408 saved to abstract_40323.txt
# ================================================================================
# 2-s2.0-85012034473
# Abstract for EID 2-s2.0-85012034473 saved to abstract_40324.txt
# ================================================================================
# 2-s2.0-85009790505
# Abstract for EID 2-s2.0-85009790505 saved to abstract_40325.txt
# ================================================================================
# 2-s2.0-85007540757
# Abstract for EID 2-s2.0-85007540757 saved to abstract_40326.txt
# ================================================================================
# 2-s2.0-85006281257
# Abstract for EID 2-s2.0-85006281257 saved to abstract_40327.txt
# ================================================================================
# 2-s2.0-85003208083
# Abstract for EID 2-s2.0-85003208083 saved to abstract_40328.txt
# ================================================================================
# 2-s2.0-84992304566
# Abstract for EID 2-s2.0-84992304566 saved to abstract_40329.txt
# ================================================================================
# 2-s2.0-84992123262
# Abstract for EID 2-s2.0-84992123262 saved to abstract_40330.txt
# ================================================================================
# 2-s2.0-84991325620
# Abstract for EID 2-s2.0-84991325620 saved to abstract_40331.txt
# ================================================================================
# 2-s2.0-84991289783
# Abstract for EID 2-s2.0-84991289783 saved to abstract_40332.txt
# ================================================================================
# 2-s2.0-84990242712
# Abstract for EID 2-s2.0-84990242712 saved to abstract_40333.txt
# ================================================================================
# 2-s2.0-84987719521
# Abstract for EID 2-s2.0-84987719521 saved to abstract_40334.txt
# ================================================================================
# 2-s2.0-84984904313
# Abstract for EID 2-s2.0-84984904313 saved to abstract_40335.txt
# ================================================================================
# 2-s2.0-84983407530
# Abstract for EID 2-s2.0-84983407530 saved to abstract_40336.txt
# ================================================================================
# 2-s2.0-84983384597
# Abstract for EID 2-s2.0-84983384597 saved to abstract_40337.txt
# ================================================================================
# 2-s2.0-84983373763
# Abstract for EID 2-s2.0-84983373763 saved to abstract_40338.txt
# ================================================================================
# 2-s2.0-84982821506
# Abstract for EID 2-s2.0-84982821506 saved to abstract_40339.txt
# ================================================================================
# 2-s2.0-84981505071
# Abstract for EID 2-s2.0-84981505071 saved to abstract_40340.txt
# ================================================================================
# 2-s2.0-84981484885
# Abstract for EID 2-s2.0-84981484885 saved to abstract_40341.txt
# ================================================================================
# 2-s2.0-84979982351
# Abstract for EID 2-s2.0-84979982351 saved to abstract_40342.txt
# ================================================================================
# 2-s2.0-84979490330
# Abstract for EID 2-s2.0-84979490330 saved to abstract_40343.txt
# ================================================================================
# 2-s2.0-84979295897
# Abstract for EID 2-s2.0-84979295897 saved to abstract_40344.txt
# ================================================================================
# Next Serial Number: 40345
